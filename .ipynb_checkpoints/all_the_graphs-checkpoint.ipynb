# %% [markdown]
# # Categorical

# %% [markdown]
# ## Bar Chart (column chart)

# %%
import pandas as pd
import requests
import bs4
import matplotlib.pyplot as plt

# %%
page = "https://en.wikipedia.org/wiki/List_of_actors_with_two_or_more_Academy_Awards_in_acting_categories"
r = requests.get(page);
r.text
soup = bs4.BeautifulSoup(r.text)

table = soup.find('table')
rows = table.find_all('tr')

arr = []
for i in rows:
    table_data = i.find_all('td')
    # table_data = table_data[0]
    data = [j.text for j in table_data]
    if len(data) == 0:
        continue
    else:
        arr.append(data)

df = pd.DataFrame(arr)

# data cleaning
df = df.drop([1, 2], axis=1)
df[0] = df[0].apply(lambda x:  x.strip("\n"))
df[0] = df[0].apply(lambda x:  x.strip("†"))
df[3] = df[3].astype(int)
df[4] = df[4].astype(int)

df = df.rename(columns = {0 : 'Actor', 3 : 'Wins', 4 : 'Nominations'})

# %%
df.sort_values(by = 'Nominations', inplace = True, ascending = False)

# %%
df.reset_index(inplace = True, drop = True)

# %%
df_red = df.iloc[:10, ]

# %%
fig, ax = plt.subplots(figsize = (15, 8), dpi = 80)

#barplot
ax.bar(x = df_red['Actor'], 
       height = df_red['Nominations'],
       width = 0.6,
       color = 'grey',
       edgecolor = 'black',
       zorder = 3)

#ticks
labels = ['\n'.join(i.split()) for i in df_red.Actor]
ax.set_xticks(range(0, 10), labels)
ax.set_yticks(range(0, 22, 2))
ax.set_ylim(0, 22)

#horizontal lines
ax.grid(zorder = 0, axis = 'y', which = 'major',
       alpha = 0.4, linewidth = 0.4)

#remove borders
for i in ['top', 'bottom', 'right', 'left']:
    ax.spines[i].set_visible(False)

#title
ax.set_title('The 10 Actors with the most Oscar nominations', fontsize = 18)

#remove tick marks
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_ticks_position('none')

plt.show()

# %% [markdown]
# ## Clustered bar chart (clustered column chart, paired bar chart)

# %%
import pandas as pd
import requests
import bs4
import matplotlib.pyplot as plt
import numpy as np


page = "https://en.wikipedia.org/wiki/List_of_actors_with_two_or_more_Academy_Awards_in_acting_categories"
r = requests.get(page);
r.text
soup = bs4.BeautifulSoup(r.text)

table = soup.find('table')
rows = table.find_all('tr')

arr = []
for i in rows:
    table_data = i.find_all('td')
    # table_data = table_data[0]
    data = [j.text for j in table_data]
    if len(data) == 0:
        continue
    else:
        arr.append(data)

df = pd.DataFrame(arr)

# data cleaning
df = df.drop([1, 2], axis=1)
df[0] = df[0].apply(lambda x:  x.strip("\n"))
df[0] = df[0].apply(lambda x:  x.strip("†"))
df[3] = df[3].astype(int)
df[4] = df[4].astype(int)

df = df.rename(columns = {0 : 'Actor', 3 : 'Wins', 4 : 'Nominations'})

df.sort_values(by = 'Nominations', inplace = True, ascending = False)

df.reset_index(inplace = True, drop = True)

df_red = df.iloc[:10, ]

# %%
fig, ax = plt.subplots(figsize = (15, 8), dpi = 80)

x = np.arange(len(df_red.index))

width = 0.35

#barplots
l_bar = ax.bar(x - 0.35 / 2, df_red['Nominations'], width = 0.35, label = 'Nominations',
              color = 'grey',
              edgecolor = 'black',
              zorder = 3)

r_bar = ax.bar(x + 0.35 / 2, df_red['Wins'], width = 0.35, label = 'Wins',
              color = 'yellow',
              edgecolor = 'black',
              zorder = 3)


#add horizontal lines
ax.grid(zorder = 0, axis = 'y', which = 'major', alpha = 0.4, linewidth = 0.4)


#add xtick labels
labels = ['\n'.join(i.split()) for i in df_red.Actor]
ax.set_xticks(range(0, 10), labels)

#set yticks
ax.set_yticks(range(0,21, 2))

#remove borders
for i in ['top', 'bottom', 'right', 'left']:
    ax.spines[i].set_visible(False)


#horizontal lines
ax.grid(zorder = 0, axis = 'y', which = 'major',
       alpha = 0.4, linewidth = 0.4)


#remove borders
for i in ['top', 'bottom', 'right', 'left']:
    ax.spines[i].set_visible(False)
    
    
#remove tick marks
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_ticks_position('none')


#legend

fig.legend(loc = 'upper center', ncol = 2, frameon = False)

#title
ax.set_title('The 10 actors who have received the most Oscar nominations', fontsize = 18)


plt.show()

# %% [markdown]
# ## Dot plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {'Taiwan' : {'male' : 2749, 'female' : 956},
        'Georgia' : {'male' : 444, 'female' : 161},
        'South Korea' : {'male' : 7172, 'female' : 3370},
        'Iran' : {'male' : 3257, 'female' : 1531},
        'Iraq' : {'male' : 3434, 'female' : 1622},
        'Jordan' : {'male' : 316, 'female' : 156},
        'Uganda' : {'male' : 673, 'female' : 341},
        'Malaysia' : {'male' : 495, 'female' : 255},
        'Saudi Arabia' : {'male' : 227, 'female' : 122},
        'Armenia' : {'male' : 393, 'female' : 221},
        'Colombia' : {'male' : 124, 'female' : 78},
        'Lebanon' : {'male' : 76, 'female' :48},
        'Czech Republic' : {'male' : 1358, 'female' :870},
        'Morocco' : {'male' : 3916, 'female' : 2564},
        'Greece' : {'male' : 1100, 'female' : 792},
        'Switzerland' : {'male' : 2196, 'female' : 1604},
        'Austria' : {'male' : 1436, 'female' : 1064},
        'Belgium' : {'male' : 1221, 'female' : 905},
        'France' : {'male' : 6856, 'female' : 5085},
        'Canada' : {'male' : 3021, 'female' : 2395},
        'Germany' : {'male' : 14506, 'female' : 11533},
        'Iceland' : {'male' : 20, 'female' : 16},
        'Turkey' : {'male' : 2591, 'female' : 2093},
        'Norway' : {'male' : 664, 'female' : 538},
        'Denmark' : {'male' : 764, 'female' : 624},
        'United Kingdom' : {'male' : 10265, 'female' : 8485},
        'Mexico' : {'male' : 2280, 'female' : 1887},
        'Chile' : {'male' : 231, 'female' : 192},
        'Madagascar' : {'male' : 307, 'female' : 258},
        'Algeria' : {'male' : 4310, 'female' : 3649},
        'Slovenia' : {'male' : 251, 'female' : 214},
        'Hungary' : {'male' : 680, 'female' : 595},
        'Spain' : {'male' : 4608, 'female' : 4088},
        'Romania' : {'male' : 2490, 'female' : 2274},
        'Ireland' : {'male' : 638, 'female' : 584},
        'Bulgaria' : {'male' : 311, 'female' : 285},
        'Sweden' : {'male' : 1744, 'female' : 1627},
        'Slovak Republic' : {'male' : 1471, 'female' : 1407},
        'United States' : {'male' : 29008, 'female' : 28397},
        'Australia' : {'male' : 5825 - 2911, 'female' : 2911},
        'Israel' : {'male' : 756, 'female' : 778},
        'Macedonia' : {'male' : 77, 'female' : 80},
        'Croatia' : {'male' : 410, 'female' : 428},
        'Italy' : {'male' : 4960, 'female' : 5228},
        'Estonia' : {'male' : 83, 'female' : 92},
        'New Zealand' : {'male' : 461, 'female' : 526},
        'Finland' : {'male' : 813, 'female' : 937},
        'Ukraine' : {'male' : 4080, 'female' : 4838},
        'Kyrgyzstan' : {'male' : 307, 'female' : 252},
        'Argentina' : {'male' : 422, 'female' : 515},
        'Mongolia' : {'male' : 61, 'female' : 75},
        'Thailand' : {'male' : 1273, 'female' : 1716},
        'Lithuania' : {'male' : 171, 'female' : 235},
        'Uruguay' : {'male' : 16, 'female' : 23},
        'Latvia' : {'male' : 53, 'female' : 79},
        'Portugal' : {'male' : 1111, 'female' : 1816}}

df = pd.DataFrame.from_dict(data).transpose()

df['perc_male'] = round(df.male / (df.male + df.female), 2)

df['perc_female'] = 1 - df['perc_male']

df.sort_values(by = 'perc_male', inplace = True, ascending = False)

# %%
fig, ax = plt.subplots(figsize = (14, 7), dpi = 300)

x = range(0, df.shape[0])

#male scatter
ax.scatter(zorder = 3, x = x, y = df.perc_male, color = 'cyan', s = df.male / 100, label = 'male')

#female scatter
ax.scatter(zorder = 3, x = x, y = df.perc_female, color = 'pink', s = df.female / 100, label = 'female')


#set ylim, and ticks
ax.set_ylim(0, 1)
ax.set_yticks(np.arange(0, 1.10, 0.1), labels = range(0, 110, 10))

#x labels
ax.set_xticks(ticks = x, labels = df.index, rotation = 90, va = 'bottom')

#add vertical line for smallest PhD gender gap

df['minimum'] = abs(df.perc_male - df.perc_female)


mn = df[df.minimum == min(df.minimum)].index[0]

mx = df[df.minimum == max(df.minimum)].index[0]

df['idx'] = range(0, df.shape[0])

idx_mn = df.idx[df.index == mn]
idx_mx = df.idx[df.index == mx]

plt.annotate('Smallest PhD Gender Gap', (idx_mn + 0.01, 0.95))
plt.annotate('Smallest PhD Gender Gap', (idx_mx + 0.01, 0.95))

plt.vlines(zorder = 0, x = idx_mn, ymin = 0.15, ymax = 1, linestyle = 'dotted', linewidth = 0.6, color = 'black')
plt.vlines(zorder = 0, x = idx_mx, ymin = 0.12, ymax = 1, linestyle = 'dotted', linewidth = 0.6, color = 'black')

#lighten borders

for i in ['top', 'bottom', 'right', 'left']:
    ax.spines[i].set_alpha(0.3)
    
#remove ticks

ax.yaxis.set_ticks_position('none')
ax.xaxis.set_ticks_position('none')

xticks = [*ax.xaxis.get_major_ticks(), *ax.xaxis.get_minor_ticks()]

for tick in xticks:
        tick.set_pad(-10)
        
plt.legend(loc = 'upper center', ncol = 2, frameon = False)
        
plt.show()

# %% [markdown]
# ## Connected dot plot (barbell chart, dumb bell chart)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'admin & organization' : {'male' : 55149, 'female' : 43801},
        'HR managers' : {'male' : 95004, 'female' : 67600},
        'Production clerks' : {'male' : 53248, 'female' : 38376},
        'Human resources' : {'male' : 65364, 'female' : 47424},
        'Accountants' : {'male' : 64272, 'female' : 51948},
        'Education admin' : {'male' : 74828, 'female' : 60892},
        'Secretaries' : {'male' : 42172, 'female' : 35620},
        'Receptionists' : {'male' : 32032, 'female' : 27664},
        'Data entry keyers' : {'male' : 34996, 'female' : 32136},
        'Office clerks' : {'male' : 34424, 'female' : 32552},
        'Care & education' : {'male' : 52827, 'female' : 44210},
        'Doctors & surgeons' : {'male' : 104104, 'female' : 64792},
        'Teacher assistants' : {'male' : 30160, 'female' : 25688},
        'Social services' : {'male' : 59384, 'female' : 50856},
        'Healthcare support' : {'male' : 29120, 'female' : 25584},
        'Nursing' : {'male' : 27456, 'female' : 24232},
        'Physical therapists' : {'male' : 76856, 'female' : 67964},
        'Secondary school' : {'male' : 57616, 'female' : 51168},
        'Emergency medical' : {'male' : 41132, 'female' : 36868},
        'Special education' : {'male' : 56056, 'female' : 51324},
        'Social workers' : {'male' : 46384, 'female' : 43628},
        'Creative & media' : {'male' : 57009, 'female' : 46280},
        'Web developers' : {'male' : 64740, 'female' : 51376},
        'Designers' : {'male' : 53040, 'female' : 42224},
        'Arts & media' : {'male' : 53248, 'female' : 43628},
        'Law & justice' : {'male' : 40444, 'female' : 31601},
        'Legal occupations' : {'male' : 91780, 'female' : 52052},
        'Protective services' : {'male' : 46072, 'female' : 32084},
        'Police officers' : {'male' : 54236, 'female' : 38636},
        'Lawyers' : {'male' : 99580, 'female' : 82680},
        'Security' : {'male' : 30628, 'female' : 26728},
        'Bailiffs & jailers' : {'male' : 39260, 'female' : 35724},
        'Traffic clerks' : {'male' : 31356, 'female' : 29952}}

df = pd.DataFrame.from_dict(data)

df = df.transpose()

df.female = df.female / 1000
df.male = df.male / 1000
# Out:
# admin & organization     55.149
# HR managers              95.004
# Production clerks        53.248
# Human resources          65.364
# Accountants              64.272
# Education admin          74.828
# Secretaries              42.172
# Receptionists            32.032
# Data entry keyers        34.996
# Office clerks            34.424
# Care & education         52.827
# Doctors & surgeons      104.104
# Teacher assistants       30.160
# Social services          59.384
# Healthcare support       29.120
# Nursing                  27.456
# Physical therapists      76.856
# Secondary school         57.616
# Emergency medical        41.132
# Special education        56.056
# Social workers           46.384
# Creative & media         57.009
# Web developers           64.740
# Designers                53.040
# Arts & media             53.248
# Law & justice            40.444
# Legal occupations        91.780
# Protective services      46.072
# Police officers          54.236
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize = (14, 8), dpi = 300)

m = ax.scatter(zorder = 3, x = df.male, y = range(0, df.shape[0]), color = '#C6CC7E', s = 30)
f = ax.scatter(zorder = 3, x = df.female, y = range(0, df.shape[0]), color = '#6B2B53', s = 30)

line = ax.hlines(y = range(df.shape[0]), xmin = df.female, xmax = df.male, color = 'black', linewidth = 0.4)

#add a secondary x for ticks
axT = ax.twiny()

axT.set_xticks(ticks = range(0, 130, 10))
axT.set_xlabel('yearly salary (thousands)')

ax.set_xticks(ticks = range(0, 130, 10), labels = range(0, 65, 5))
ax.set_xlabel('hourly rate')

#vertical grid
ax.grid(zorder = 0, which = 'major', axis = 'x')

ax.set_yticks(ticks = range(0, df.shape[0]), labels = df.index[::-1])

#remove tick marks
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_ticks_position('none')
axT.xaxis.set_ticks_position('none')

plt.show()

# %% [markdown]
# ## Pictogram (isotype chart, pictorial bar chart, stacked shape chart, tally chart)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle
from matplotlib.patches import Patch

# %%
data = {'Rangers' : {'full_beard' : 13, 'light_beard' : 6, 'clean' : 0},
        'Blackhawks' : {'full_beard' : 10, 'light_beard' : 8, 'clean' : 1},
        'Ducks' : {'full_beard' : 10, 'light_beard' : 6, 'clean' : 3},
        'Lightning' : {'full_beard' : 10, 'light_beard' : 6, 'clean' : 3}}

df = pd.DataFrame.from_dict(data)

idx = 0

for i in df.columns:
    
    #create a waffle for each category
    
    plt.figure(FigureClass = Waffle,
            rows = 1,
            columns = eval(f'sum(df.{i}.values)'),
            values = eval(f'df.{i}.values'),
            icons = 'star',
            colors = ['black', 'grey', 'pink'],
            interval_ratio_x = 2,
            interval_ratio_y = 0,
            font_size = 20,
            figsize = (12, 8),
            dpi = 300)
    
    #left annotation for column name
    plt.annotate(f'{i}', (-5, 0), annotation_clip = False, fontsize = 10, weight = 'bold')
    
    
    #for the first plot we create a legend to put on top
    
    if idx == 0:
        legend_elems = [Patch(facecolor = 'black', label = 'full beard'),
                Patch(facecolor = 'grey', label = 'light beard'),
                Patch(facecolor = 'pink', label = 'clean')]
        plt.legend(handles = legend_elems, loc = 'upper center', bbox_to_anchor = (0.5, 3.5), ncol = 3, frameon = False)
        
    idx += 1
    
    

plt.tight_layout()
plt.show()

#I don't know how to fix this, but even if it seems like there is one unique plot, actually there are 4 of them, in fact you
#can zoom on them separately by double-clicking.
# Out:
# <Waffle size 3600x2400 with 1 Axes>
# <Waffle size 3600x2400 with 1 Axes>
# <Waffle size 3600x2400 with 1 Axes>
# <Waffle size 3600x2400 with 1 Axes>

# %% [markdown]
# ## Proportional shape chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches

# %%
data = {'Pharma/Research' : {'amount' : 1500000000},
        'Producer' : {'amount' : 645000000},
        'Consumer' : {'amount' : 302000000},
        'Real Estate' : {'amount' : 216000000},
        'Consulting' : {'amount' : 170000000},
        'Tech' : {'amount' : 162000000},
        'Industrials' : {'amount' : 54000000}}

# %% [markdown]
# ## Bubble chart (circle packing diagram)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import circlify

# %%
#unity measure of datum is billions

data = [{'id' : 'all', 'datum' : 56.114 + 36.484 + 29.897 + 38.436 + 10.949 + 134.108 + 11.874 + 84.261 + 257.562 + 3.724, 'children' :
        
         [{'id' : 'Social protection', 'datum' : 257.562, 'children' :
         [{'id' : 'Old age', 'datum' : 118.195},
          {'id' : 'Sickness and disability', 'datum' : 49.982},
          {'id' : 'Social exclusion s.n.c.', 'datum' : 29.329},
          {'id' : 'Housing', 'datum' : 26.569},
          {'id' : 'Family and children', 'datum' : 24.879},
          {'id' : 'Unemployment', 'datum' : 3.473},
          {'id' : 'Survivors', 'datum' : 1.122},
          {'id' : 'Social protection n.e.c.', 'datum' : 4.013},
          #{'id' : 'R&D social protection', 'datum' : 0}
         ]},
         
         {'id' : 'Health', 'datum' : 134.108, 'children' :
         [{'id' : 'Medical services', 'datum' : 128.871},
          {'id' : 'Central and other health services', 'datum' : 42.21},
          {'id' : 'Medical research', 'datum' : 1.016}
         ]},
          
        {'id' : 'Education', 'datum' : 84.261, 'children' : 
         [{'id' : 'Secondary education', 'datum' : 36.847},
          {'id' : 'Pre-primary and primary education', 'datum' : 31.089},
          {'id' : 'Tertiary education', 'datum' : 10.308},
          {'id' : 'Subsidary services to education', 'datum' : 2.878},
          {'id' : 'Education n.e.c.', 'datum' : 2.179},
          {'id' : 'Education not definable by level', 'datum' : 0.842},
          {'id' : 'Post-secondary non-tertiary education', 'datum' : 0.108},
          #{'id' : 'R&D education', 'datum' : 9}  
         ]},
          
        {'id' : 'General public services', 'datum' : 56.114, 'children' :
         [{'id' :  'Executive and legislative organs, financial and fiscal affairs, external affairs', 'datum' : 10.764},
          {'id': 'Public debt transaction', 'datum' : 33.523},
          {'id' : 'Foreign economic aid', 'datum' : 8.842},
          {'id' : 'General public services n.e.c.', 'datum' : 2.162},
          {'id' : 'General services', 'datum' : 0.813},
          {'id' : 'R&D general public services', 'datum' : 0.011},
          #{'id' : 'Basic research', 'datum' : 0}
         ]},
          
         {'id' : 'Economic affairs', 'datum' : 38.436, 'children' :
         [{'id' : 'Transport', 'datum' : 20.524},
          {'id' : 'Agriculture, forestry, fishing and hunting', 'datum': 5.116},
          {'id' : 'R&D economic affairs', 'datum' : 4.940},
          {'id' : 'Economics affairs n.e.c.', 'datum' : 0.525},
          {'id' : 'Fuel and energy', 'datum' : 0.445},
          {'id' : 'Communication', 'datum' : 0.432},
          {'id' : 'Other industries', 'datum' : 0.297},
          {'id' : 'Mining, manufacturing and construction', 'datum' : 0.029},
         ]},
          
        {'id' : 'Defence', 'datum' : 36.484, 'children' : 
         [{'id' : 'Military defence', 'datum' : 32.884},
          {'id' : 'R&D defence', 'datum' : 2.599},
          {'id' : 'Foreign military aid', 'datum' : 0.621},
          {'id' : 'Defence n.e.c.', 'datum' : 0.261},
          {'id' : 'Civil defence', 'datum' : 0.119}
         ]},
          
        {'id' : 'Public order and safetly', 'datum' : 29.897, 'children' :
         [{'id' : 'Police services', 'datum' : 16.877},
          {'id' : 'Law courts', 'datum' : 5.494},
          {'id' : 'Prisons', 'datum' : 3.789},
          {'id' : 'Fire-protection services', 'datum' : 2.875},
          {'id' : 'Public order and safetly n.e.c.', 'datum' : 0.829},
          {'id' : 'R&D public order and safetly', 'datum': 0.032}
         ]},
          
        {'id' : 'Recreation, culture and religion', 'datum' : 11.874, 'children' : 
         [{'id' : 'Broadcasting and publishing services', 'datum' : 4.226},
          {'id' : 'Cultural services', 'datum' : 4.014},
          {'id' : 'Recreational and sporting services', 'datum' : 3.353},
          {'id' : 'R&D recreation, culture and religion', 'datum' : 0.132},
          {'id' : 'Religious and other community services', 'datum' : 0.083},
          {'id' : 'Recreation, culture and religion n.e.c.', 'datum' : 0.066}
         ]},
         
        {'id' : 'Environment protection', 'datum' : 10.949, 'children' :
         [{'id' : 'Waste management', 'datum' : 8.282},
          {'id' : 'Environment protection n.e.c.', 'datum' : 2.113},
          {'id' : 'Pollution abatement', 'datum' : 0.482},
          {'id' : 'Protection of biodiversity and landscape', 'datum' : 0.481},
          {'id' : 'R&D environment protection', 'datum' : 0.368},
          #{'id' : 'Waste water management', 'datum' : 0},
         ]},
          
        {'id' : 'EU transactions', 'datum' : 3.724, 'children' :
         [{'id' : 'GNI-based contribution', 'datum' : 8.127},
          #{'id' : 'Attributed aid and Common Foreign and Security Policy', 'datum' : 0}
         ]}
    ]}]

# %%
#0 values have to be removed first, and data has to be sorted in descending order within each children folder

  
circles = circlify.circlify(data,
                           show_enclosure = False,
                           target_enclosure = circlify.Circle(x = 0, y = 0, r = 0.3),
                           datum_field = 'datum',
                           id_field = 'id',
                           children_field = 'children')

# %%
fig, ax = plt.subplots(figsize = (40, 40), dpi = 300)

ax.set_title('Services expenditure - 2015', fontsize = 50)

ax.axis('off')

lim = max(
max(abs(circle.x) + circle.r,
    abs(circle.y) + circle.r,
   )
    for circle in circles
)
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)


#list of colors         #health      #edu     #public   #econ aff   #milit     #safetly    #relig    #environ  #EU trans
l_colors = ['#cabcda', '#db2c2c', '#9a74b0', '#2083bd', '#fac285', '#b7ceeb', '#f28a1f', '#f4a1a1', '#33ab3f', '#976257']


#color dictionary
col_diz = {}

idx = -1

for i in data[0]['children']:
    idx += 1
    for j in i['children']:
        col_diz[j['id']] = idx


#plot circles which are at level > 2, changing color accordingly
for circle in circles:
    if circle.level > 2:
        x, y, r = circle
        label = f"{circle.ex['id']}\n{circle.ex['datum']}"
        label = label.split()
        
        a, b = [i for i in label[:3] if not i.replace('.', '', 1).isnumeric()], f'£{label[-1]}mlns'
        l = a + [b]
        l = '\n'.join(l)
        
        #add circle
        ax.add_patch(plt.Circle((x, y), r, linewidth = 2, color = l_colors[col_diz[' '.join(label[:-1])]]))
        
        if r > 0.03:
            #add text if radius is sufficiently big and adapt its dimension based on radius
            plt.annotate(l, (x, y), va = 'center', ha = 'center', color = 'white', fontsize = r * 700, weight = 'bold')
            
#legend
custom_legend = legend_elems = [Patch(facecolor = '#cabcda', label = 'Social protection'),
                                Patch(facecolor = '#db2c2c', label = 'Medical services'),
                                Patch(facecolor = '#9a74b0', label = 'Education'),
                                Patch(facecolor = '#2083bd', label = 'General Public Services'),
                                Patch(facecolor = '#fac285', label = 'Economic affairs'),
                                Patch(facecolor = '#b7ceeb', label = 'Defence'),
                                Patch(facecolor = '#f28a1f', label = 'Public order and safetly'),
                                Patch(facecolor = '#f4a1a1', label = 'Recreation, culture and religion'),
                                Patch(facecolor = '#33ab3f', label = 'Environment protection'),
                                Patch(facecolor = '#976257', label = 'EU transactions')]

plt.legend(handles = custom_legend, loc = 'upper right', ncol = 1, frameon = False, prop = {'size' : 28})

plt.tight_layout()

plt.show()
